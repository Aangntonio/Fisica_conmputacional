# %%
import numpy as np
import matplotlib.pyplot as plt 

import sys 
i = sys.maxsize

print(i)

f1 = sys.float_info.max

f2 = sys.float_info.min

eps = sys.float_info.epsilon


print(f1, f2,eps)
# Out:
# 9223372036854775807
# 1.7976931348623157e+308 2.2250738585072014e-308 2.220446049250313e-16

# %%
def barkara(a,b,c):
    '''
    Esta función puede resolver una ecuacion cuadratica con :
    a: 
    b:
    c:
    '''
    if b**2- 4 * a * c <0:
        raise ValueError('La solucion no esta definida en R')
    if a == 0:
        raise ValueError('a debe ser distindo de 0')
        
    dis = np.sqrt(b**2 - 4*a*c)
    x1 = (-b+  dis)/ (2*a)
    x2 = (-b-  dis)/(2*a)
    
    f = lambda x: a*x**2 + b*x + c 
    x = np.linspace(-10,10,101)
    
    plt.plot(x,f(x))
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.scatter(x1, 0, color='red', marker='o')
    plt.scatter(x2, 0, color='red', marker='o')
    plt.grid()
    plt.show()
    
    
    return 'las soluciones a tu ecuacion son', x1,' y', x2

# %%
for i in range(1,10,2):
    barkara(-i,1/i,i)
    #barkara(i,0,-i)

# %%
s = 1.1
suma = 1

for i in range(1,1000001):
    suma += 0.0000001

err = suma - s  
print('la suma es {0:} con'.format(suma),'como un error de ', err)
# Out:
# la suma es 1.1000000000583867 con como un error de  5.838662886503698e-11

# %%
 
suma = 1.0

for i in range(1,1001):
    total = 0.0
    for j in range(1,1001):
        total += 0.0000001
    suma = suma + total
    
err = (1.1-suma) / 1.1 
print('la suma es {0:} con un error de {1:}'.format(nueva_suma,err))
# Out:
# la suma es 1.1002001000000474 con un error de 1.0092936587501423e-14

# %%
np.log(2)
# Out:
# 0.6931471805599453
